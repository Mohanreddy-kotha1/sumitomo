# %%
import pandas as pd
p = r"C:\Users\mohanreddykotha\sumitomo_datalake\sumitomo\data\bronze_delta\Slovakia\REPORT_X_SLOVAKIA__Sheet1\part-00001-3e05bdd7-3870-4ec7-8f3a-e6bf0b6c053c-c000.snappy.parquet"
df = pd.read_parquet(p)
# print(df.head(10))

print(df.columns.tolist())

print(f"{len(df.columns)} columns:")
for i, c in enumerate(df.columns, 1):
    print(f"{i}. {c}")

print(*df.columns, sep="\n")
# Out:
# ['ORDER_NO', 'MODEL_2', 'ORDER_DATE', 'ORD_SALES_TYPE', 'DEALER_PRIORITY', 'ROAR', 'ROAR_DATE', 'CONTRACT_PROCESS_DATE', 'LOCATION', 'PLANT', 'STATUS_ORDER', 'STATUS_DATE', 'ORDER_FEASIBLE_IND', 'HOLDEND_DATE', 'HOLD_XX', 'HOLD_TYPE', 'VIN_PREFIX', 'VIN', 'PLAN_BUILD_DATE', 'SEGMENTED_BUILD_DATE', 'GATE_REL_DATE', 'ETA_DATE', 'NDC_IN_DATE', 'DLR_DELIVERY_DATE', 'MODEL_YEAR', 'BODY', 'SERIES', 'SVP', 'ENGINE', 'TRANSMISSION', 'COLOUR', 'TRIM', 'OPTION_LIST', 'ORDER_DATE_VER2', 'BUILD_DATE', 'PROD_DATE_V2', 'AGE', 'RETAIL_YR', 'RETAIL_MTH', 'OPT1', 'OPT2', 'OPT3', 'OPT4', 'OPT5', 'OPT6', 'OPT7', 'OPT8', 'OPT9', 'OPT10', 'OPT11', 'OPT12', 'OPT13', 'OPT14', 'OPT15', 'OPT16', 'OPT17', 'OPT18', 'OPT19', 'OPT20', 'OPT21', 'OPT22', 'OPT23', 'OPT24', 'OPT25', 'CO2_SOURCE', 'WLTP_CO2_EX_HIGH', 'WLTP_CO2_HIGH', 'WLTP_CO2_LOW', 'WLTP_CO2_MED', 'WLTP_CO2_OVERALL', 'WLTP_FC_OVRL', 'WLTP_FC_LOW', 'WLTP_FC_MED', 'WLTP_FC_HIGH', 'WLTP_FC_EX_HIGH', 'WLTP_DATE', 'WLTP_TIMESTAMP', 'DELAY_CODE', 'SB_Code
# ...

# %%
p = r"C:\Users\mohanreddykotha\sumitomo_datalake\sumitomo\data\bronze_delta\Slovakia\REPORT_X_SLOVAKIA__Sheet1\part-00001-3e05bdd7-3870-4ec7-8f3a-e6bf0b6c053c-c000.snappy.parquet"
df = pd.read_parquet(p)
print(df.head(10))
# Out:
#   ORDER_NO              MODEL_2           ORDER_DATE ORD_SALES_TYPE  \
# 0    A0034          V710 CAMPER  2025-01-08 00:00:00              A
# 1    B1262          V710 CAMPER  2025-02-26 00:00:00              S
# 2    B1263          V710 CAMPER  2025-02-26 00:00:00              S
# 3    B1083          V710 CAMPER  2025-02-14 00:00:00              S
# 4    B1084          V710 CAMPER  2025-02-14 00:00:00              S
# 5    B1264          V710 CAMPER  2025-02-26 00:00:00              S
# 6    B0449          V710 CAMPER  2025-02-04 00:00:00              A
# 7    E0099       C519 MCA FOCUS  2025-05-06 00:00:00              A
# 8    G1026  V710 TRANSIT CUSTOM  2025-07-15 00:00:00              S
# 9    B0810  V710 TOURNEO CUSTOM  2025-02-05 00:00:00              A
#
#   DEALER_PRIORITY ROAR            ROAR_DATE CONTRACT_PROCESS_DATE   LOCATION  \
# 0              01    1  2025-04-07 00:00:00   2025-04-07 00:00:00  ORDERBANK
# ...
